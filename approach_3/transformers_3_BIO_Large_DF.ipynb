# %% [markdown]
# <div style="padding: 0.5em; background-color: #1876d1; color: #fff; font-weight: bold; font-size: 1.4em;">
#     [Approach 3]  Location Mention Recognition - NER BERT Transformer
# </div>
#
# In this Jupyter notebook, we will use Name Entity Recognition to extract from X (Twitter formely) tweets Location Mention from Emergency Situation.
#
# Note :
# * Do NER
# * Try BERT Model
# * Extract Location Mention
# * The BIO format is very specific. It requires an understanding of tokens being “Inside” (I) and “Outside” (O) a particular entity label. This would add unnecessary complexity in formulating a task description prompt. Idea is to try IO formating approach
#
# ---
# <b>#Microsoft Learn Challenge, #Zindi, #Hamad Bin Khalifa University </b>

# %% [markdown]
# ### **Importing Library**

# %%
#!pip install simpletransformers
#!pip install pyspellchecker
#!pip install stanza
#!pip install nltk
#!pip install python-dotenv
#!pip install werpy
#!pip install wandb
#!pip install deep_utils

# %%
# general utils
import werpy
import numpy as np
import pandas as pd
import seaborn as sns
import stanza, os, sys, re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from simpletransformers.ner import NERModel, NERArgs
pd.set_option('display.max_colwidth', 300)

# utils setup
current_directory = os.getcwd()
root_directory = os.path.abspath(os.path.join(current_directory, os.pardir))
sys.path.append(root_directory)

# logging
import wandb
os.environ["WANDB_NOTEBOOK_NAME"] = "transformers_3_BIO_and_IO.ipynb"

# custom utils
from utils.io import Predictions
from utils.metrics import LMR_Metrics
from utils.io import LMR_BILOU_Scrapper, LMR_JSON_Scrapper
from utils.preprocessing import Preprocess
from utils.stratify import MultiLabelNERStratify

# %% [markdown]
# ### **Exploring Data**
#
# The provided Train.csv contain many missing value so we have to get data from initial source.

# %%
#LMR_JSON_Scrapper(output_dir="../data/self_scrapped/raw").run()

# %% [markdown]
# - Let concatenate out dataset

# %%
train_dfs = []
dev_dfs   = []
path_dfs  = "../data/self_scrapped/raw"
for filename in os.listdir(path_dfs):
    if filename.endswith(".csv"):
        file_path = os.path.join(path_dfs, filename)
        if filename.startswith("train"):
            df = pd.read_csv(file_path)
            train_dfs.append(df)
        elif filename.startswith("dev"):
            df = pd.read_csv(file_path)
            dev_dfs.append(df)

df_train = pd.concat(train_dfs, ignore_index=True) if train_dfs else pd.DataFrame()
df_dev   = pd.concat(dev_dfs, ignore_index=True) if dev_dfs else pd.DataFrame()

df_train = pd.concat([df_train, df_dev])
print("TRAIN SHAPE: ", df_train.shape)
# Out:
# TRAIN SHAPE:  (16448, 3)

# %% [markdown]
# - Une augmented df

# %%
df = pd.read_csv('../data/provided/TrainEncoded.csv')

def parse_location_mentions(location_mentions):
    location_dict = {}
    if pd.notna(location_mentions):
        parts = location_mentions.split(' * ')
        for part in parts:
            location, loc_type = part.split('=>')
            location_dict[location.strip()] = loc_type.strip()
    return location_dict

location_type_dict = {}
for location in df_train['location_mentions'].dropna():
    location_type_dict.update(parse_location_mentions(location))

def label_location(row, location_type_dict):
    location = row['location']
    labeled_locations = []
    words = location.split()
    
    while words:
        for i in range(len(words), 0, -1):
            sub_location = ' '.join(words[:i]).strip()
            if sub_location in location_type_dict:
                labeled_locations.append(f"{sub_location}=>{location_type_dict[sub_location]}")
                words = words[i:]
                break
        else:
            words = words[:-1]
    if labeled_locations:
        return ' * '.join(labeled_locations)
    else:
        return None

df['location_mentions'] = df.apply(lambda row: label_location(row, location_type_dict), axis=1)
df.head(60)
# Out:
#                   tweet_id  \
# 0   ID_1001136212718088192
# 1   ID_1001136696589631488
# 2   ID_1001136950345109504
# 3   ID_1001137334056833024
# 4   ID_1001138374923579392
# 5   ID_1001138377717157888
# 6   ID_1001139323075416064
# 7   ID_1001140017207459840
# 8   ID_1001140276377935872
# 9   ID_1001140804503601152
# 10  ID_1001141041926492160
# 11  ID_1001141195576258560
# 12  ID_1001141289323319296
# 13  ID_1001141769155891200
# 14  ID_1001142381012508672
# 15  ID_1001143589630427136
# 16  ID_1001143679267098624
# 17  ID_1001144018451955712
# 18  ID_1001144314897018880
# 19  ID_1001144944717914112
# 20  ID_1001146215441068032
# 21  ID_1001146463701872640
# 22  ID_1001147515360677888
# 23  ID_1001147793904427008
# 24  ID_1001148349364490240
# 25  ID_1001148569863237632
# 26  ID_1001150622379503616
# 27  ID_1001150946028666880
# 28  ID_1001152279368683520
# 29  ID_1001152706374000640
# 30  ID_1001152750418350080
# 31  ID_1001152773814185984
# 32  ID_1001152780147576832
# 33  ID_1001153932310216704
# 34  ID_1001154242273533952
# 35  ID_1001155244011720704
# 36  ID_1001155359002607616
# 37  ID_1001155564901199872
# 38  ID_1001155973187162112
# 39  ID_1001156365992284160
# 40  ID_1001156790275510272
# 41  ID_1001156881220448256
# 42  ID_1001157849584566272
# 43  ID_1001158582619000832
# 44  ID_1001161182366126080
# 45  ID_1001161326020956160
# 46  ID_1001162007138185216
# 47  ID_1001162370390155264
# 48  ID_1001163799326425088
# 49  ID_1001164079187267584
# 50  ID_1001165180938719232
# 51  ID_1001165202870751232
# 52  ID_1001165258843664384
# 53  ID_1001165784016674816
# 54  ID_1001166109771431936
# 55  ID_1001166885130592256
# 56  ID_1001166979074412544
# 57  ID_1001168665688051712
# 58  ID_1001168701406593024
# 59  ID_1001169406649659392
#
#                                                                                                                                                                                                                                                               text  \
# 0                                                                                                                                                                                                                 EllicottCity is known for its vibrant art scene.
# 1                                                                                                                                                              Flash floods struck a Maryland city on Sunday, washing out streets and tossing cars like bath toys.
# 2                                                                                                                                                                                                 State of emergency declared for Maryland flooding:  via @YouTube
# 3                                                Other parts of Maryland also saw significant damage from Sundays storms including this Baltimore city neighborhood, #Dundalk and #Catonsville. Rain totals spanned from 1 to 10 inches across Maryland:  #ECFlood
# 4                                                                                                                                               Catastrophic Flooding Slams Ellicott City, Maryland; Water Rescues Reported - The Weather Channel  via @GoogleNews
# 5                                                                                                                                                                                 WATCH: 1 missing after flash #FLOODING devastates Ellicott City, Maryland  #GPWX
# 6                                                                                                                                                                                          The scenic spots in Ellicott City Maryland are perfect for photography.
# 7                                                                                                                                                                                                                  Maryland has a variety of historical landmarks.
# 8                                                                                                                                                                                                   The local food markets in Maryland are a feast for the senses.
# 9                                                                                                                                                                                            Baltimore is a popular destination for both relaxation and adventure.
# 10                                                                                                                                                                                                          Maryland is known for its beautiful parks and gardens.
# 11                                                                                                                                                                                                                  Ellicott Maryland has a rich musical heritage.
# 12                                                                                                                                                                                                           Maryland has a variety of family-friendly activities.
# 13                                                                                                                                                                         Watch Live: Aerials of damage after historic flash flooding in Ellicott City, Maryland.
# 14                                                                                                                                                                                          The local arts and crafts markets in Maryland are vibrant and diverse.
# 15                                                                                                                                      One person is reported missing as a state of emergency is declared amid flash floods in Maryland, @kristendahlgren reports
# 16                                                                        Monday May 28 - Morning Report: National Guardsman missing after monstrous floods sink Maryland town; Trump visits Arlington after critics slam appalling Memorial Day tweet Via @nypost
# 17                                                                                                                                                                                            The parks and gardens in Ellicott Maryland offer a peaceful retreat.
# 18                                                                                                                                        One man is still missing after flash flooding tore down historic Main Street in Ellicott City, Maryland over the weekend
# 19                                                                                                                                                                          RT @KCCINews: State of emergency declared in Maryland after heavy rain causes flooding
# 20                                                                Howard County Executive Allan Kittleman said Monday morning that his priorities are finding the missing man and assessing the condition of buildings that house shops, restaurants and families.
# 21                                                                                                                                                                                          The annual parades in Howard Ellicott Maryland are a major attraction.
# 22                                                                                                                                        JUST IN: Governor Larry Hogan has declared a state of emergency for the entire state of Maryland after extreme flooding.
# 23                                                                                                                                                                               Howard County officials searching for man reported missing in Ellicott City flood
# 24                                                                                                                                                                                               The cultural events in Baltimore Maryland highlight its heritage.
# 25                                           AdvantaClean of Frederick is available to help mitigate the damages to homes and businesses in Ellicott City and surrounding areas. Call 877-800-2382 toll free to connect with our office to get the job done right.
# 26                                                                                                                                                                    Historic Maryland city is ravaged by flood waters again. Search is underway for missing man.
# 27                                                              Army National Guardsman missing after massive flooding hits Ellicott City, Maryland. Thoughts and prayers with Eddison Alexander Hermond and his family. I sure hope they find him alive and well.
# 28                                                                                                                                                            RT @CristianiCasco: State of Emergency declared. Catastrophic flooding slams #EllicottCity #Maryland
# 29                                                          Please pray for a brave vet who is missing in Maryland in the flooding. Ellicott City, Maryland flash floods leave National Guard member missing, devastate town recovering from 2016 deluge  #FoxNews
# 30                                                                                                                                                                                    Colombia Ellicott Maryland is known for its scenic views and natural beauty.
# 31                                                                                                                                                                                                  Ellicott City Maryland is a hub for technology and innovation.
# 32                                                       A state of emergency has been declared in the US state of #Maryland as catastrophic flash floods swept Ellicott City after heavy rain. Officials have urged residents to go to higher ground immediately.
# 33                                                                                                                                                                                                  Ellicott Maryland has a variety of family-friendly activities.
# 34                                                                                                                                                             I liked a @YouTube video  CRAZY MARYLAND FLOODING - Flash flood smashes into Ellicott City Maryland
# 35                                                                                                                                                                     National Guard member missing after flash floods devastate historic Maryland town  #FoxNews
# 36                                   : Missing #NationalGuardsman, #EddisonHermond, swept away in #EllicottCity, #Maryland #floods while saving others: #MemorialDay: .@RevJJackson @SantitaJ: SUN: 8-10aE/866.594.HOPE/#iHeartRadio: @PatriotAM1150/#FacebookLive
# 37    @abcworldnewstonight - IN A FLASH: Crews have begun removing heavy debris – including cars and a dumpster – thrown by a wall of water that rushed through downtown Ellicott City, Maryland Sunday afternoon; 1 person remains missing as the town deals with
# 38                                                                                                                                                                             Maryland Hit By Catastrophic Flash Flooding, Second Time in Two Years  via @YouTube
# 39                                                                                                                                                                                                      Maryland is famous for its unique architectural landmarks.
# 40                                                                                                                                                                                              Flash Floods Surge Through Town in Maryland, One Person Is Missing
# 41                                                                                                                                                                                  The local theater performances in Ellicott City Maryland are highly acclaimed.
# 42                                                                                                                                                                                                The local history and traditions in Maryland are well-preserved.
# 43                                                                                                                                              National Guardsman missing after flash flooding devastates Ellicott City, Maryland: ‘I’m hopeful that he’ll be OK’
# 44                                                                                                           During the devastating Maryland flash floods, witnesses said Eddison Alexander was swept away while helping a woman cross the waters in Ellicott City
# 45                                                                                                             Headed to the Howard County Food Bank with supplies. Please consider joining and bringing cleaning supplies, food and water. #ECStrong #ElliottCity
# 46                                                                                     Man missing after 1,000-year flood ravages Ellicott City for 2nd time in two years  Good thing Trump & his quislings are taking such good care of us - What climate change?
# 47                                                                                                                                   Officials in Maryland are looking for a National Guard member and Air Force veteran they say was swept away in weekend floods
# 48                                                                                                                                                                                          Maryland man missing after Ellicott City devastated by rampaging flood
# 49                                                                                                                                                                                                             The community events in Maryland are well-attended.
# 50                                                                                                                                                                                                                The public libraries in Maryland are impressive.
# 51                                                                                                                                                                                                             Maryland is a top destination for cultural tourism.
# 52                                                                                                                                                   RT @TIME: Hopeful that he will be OK.” Search underway for man missing in Ellicott City, Maryland flash flood
# 53  Its even worse: Ellicott City, Maryland, recovering from 2016 flood, hammered again  #flooding 25- to 30-ft-wide hole N of Main Street, ground and road buckled. utilities off, water ran thru bldgs, Patapsco River up 17.8 ft in 2 hrs, Sunday, record level
# 54                                                                           Watch Video Severe flooding in Ellicott City, Maryland, has submerged vehicles, forced residents to evacuate and caused major damage to homes and businesses. Newsys partners at WMAR
# 55                                                                                                     Have you seen Eddison Hermond? The Army National Guard member is missing after devastating floods rolled through Ellicott City, Maryland, over the weekend.
# 56                                                                                               Emergency workers are searching for 39-year-old Eddison Hermond in Ellicott City, which was hit hard Sunday evening by flash flooding from an intense rain storm.
# 57                                                                                                                            Search underway for a missing veteran, Eddison Hermond, reportedly swept away helping to rescue others from flash floods in Maryland
# 58                                                                                                                                                                                             Ellicott Maryland is known for its scenic views and natural beauty.
# 59                                                                                                                                                        @missingpeople @MissingKids #MemorialDay ἟A἟8Ὢ8ATTENTIONὪ8἟A἟8 MISSING HERO IN FLOOD WATERS in Maryland!
#
#                                  location  \
# 0                            EllicottCity
# 1                                Maryland
# 2                                Maryland
# 3                      Baltimore Maryland
# 4                  Ellicott City Maryland
# 5                  Ellicott City Maryland
# 6                  Ellicott City Maryland
# 7                                Maryland
# 8                                Maryland
# 9                               Baltimore
# 10                               Maryland
# 11                      Ellicott Maryland
# 12                               Maryland
# 13                 Ellicott City Maryland
# 14                               Maryland
# 15                               Maryland
# 16                     Arlington Maryland
# 17                      Ellicott Maryland
# 18                 Ellicott City Maryland
# 19                               Maryland
# 20                                 Howard
# 21               Howard Ellicott Maryland
# 22                               Maryland
# 23            Ellicott City Howard County
# 24                     Baltimore Maryland
# 25                          Ellicott City
# 26                               Maryland
# 27                 Ellicott City Maryland
# 28                               Maryland
# 29                      Ellicott Maryland
# 30             Colombia Ellicott Maryland
# 31                 Ellicott City Maryland
# 32              Ellicott City US Maryland
# 33                      Ellicott Maryland
# 34        Ellicott City MARYLAND Maryland
# 35                               Maryland
# 36                  EllicottCity Maryland
# 37                 Ellicott City Maryland
# 38                               Maryland
# 39                               Maryland
# 40                               Maryland
# 41                 Ellicott City Maryland
# 42                               Maryland
# 43                 Ellicott City Maryland
# 44                 Ellicott City Maryland
# 45                          Howard County
# 46                          Ellicott City
# 47                               Maryland
# 48                 Ellicott City Maryland
# 49                               Maryland
# 50                               Maryland
# 51                               Maryland
# 52                 Ellicott City Maryland
# 53  Ellicott City Patapsco River Maryland
# 54                 Ellicott City Maryland
# 55                      Ellicott Maryland
# 56                          Ellicott City
# 57                               Maryland
# 58                      Ellicott Maryland
# 59                               Maryland
#
#                                                                     location_mentions
# 0                                                                  EllicottCity=>CITY
# 1                                                                     Maryland=>STATE
# 2                                                                     Maryland=>STATE
# 3                                                   Baltimore=>CITY * Maryland=>STATE
# 4                                               Ellicott City=>CITY * Maryland=>STATE
# 5                                               Ellicott City=>CITY * Maryland=>STATE
# 6                                               Ellicott City=>CITY * Maryland=>STATE
# 7                                                                     Maryland=>STATE
# 8                                                                     Maryland=>STATE
# 9                                                                     Baltimore=>CITY
# 10                                                                    Maryland=>STATE
# 11                                                   Ellicott=>CITY * Maryland=>STATE
# 12                                                                    Maryland=>STATE
# 13                                              Ellicott City=>CITY * Maryland=>STATE
# 14                                                                    Maryland=>STATE
# 15                                                                    Maryland=>STATE
# 16                                                Arlington=>COUNTY * Maryland=>STATE
# 17                                                   Ellicott=>CITY * Maryland=>STATE
# 18                                              Ellicott City=>CITY * Maryland=>STATE
# 19                                                                    Maryland=>STATE
# 20                                                                     Howard=>COUNTY
# 21                                  Howard=>COUNTY * Ellicott=>CITY * Maryland=>STATE
# 22                                                                    Maryland=>STATE
# 23                                        Ellicott City=>CITY * Howard County=>COUNTY
# 24                                                  Baltimore=>CITY * Maryland=>STATE
# 25                                                                Ellicott City=>CITY
# 26                                                                    Maryland=>STATE
# 27                                              Ellicott City=>CITY * Maryland=>STATE
# 28                                                                    Maryland=>STATE
# 29                                                   Ellicott=>CITY * Maryland=>STATE
# 30                               Colombia=>COUNTRY * Ellicott=>CITY * Maryland=>STATE
# 31                                              Ellicott City=>CITY * Maryland=>STATE
# 32                                Ellicott City=>CITY * US=>COUNTRY * Maryland=>STATE
# 33                                                   Ellicott=>CITY * Maryland=>STATE
# 34                            Ellicott City=>CITY * MARYLAND=>STATE * Maryland=>STATE
# 35                                                                    Maryland=>STATE
# 36                                               EllicottCity=>CITY * Maryland=>STATE
# 37                                              Ellicott City=>CITY * Maryland=>STATE
# 38                                                                    Maryland=>STATE
# 39                                                                    Maryland=>STATE
# 40                                                                    Maryland=>STATE
# 41                                              Ellicott City=>CITY * Maryland=>STATE
# 42                                                                    Maryland=>STATE
# 43                                              Ellicott City=>CITY * Maryland=>STATE
# 44                                              Ellicott City=>CITY * Maryland=>STATE
# 45                                                              Howard County=>COUNTY
# 46                                                                Ellicott City=>CITY
# 47                                                                    Maryland=>STATE
# 48                                              Ellicott City=>CITY * Maryland=>STATE
# 49                                                                    Maryland=>STATE
# 50                                                                    Maryland=>STATE
# 51                                                                    Maryland=>STATE
# 52                                              Ellicott City=>CITY * Maryland=>STATE
# 53  Ellicott City=>CITY * Patapsco River=>NATURAL POINT-OF-INTEREST * Maryland=>STATE
# 54                                              Ellicott City=>CITY * Maryland=>STATE
# 55                                                   Ellicott=>CITY * Maryland=>STATE
# 56                                                                Ellicott City=>CITY
# 57                                                                    Maryland=>STATE
# 58                                                   Ellicott=>CITY * Maryland=>STATE
# 59                                                                    Maryland=>STATE

# %% [markdown]
# ### **Preprocessing Data**
#
# - Remove special character
# - Treat HASHTAG, USERTAG
# - Remove stop word
# - Tokenization
# - Stemming
# - BIO Tagging
#
# ##### **<> BIO Tagging**
#
# BIO stands for Begin, Inside, and Outside. It’s a method for tagging tokens (words or subwords) in a sequence to identify entities within the text. Each token in the text is assigned a tag that indicates whether it is at the beginning of an entity, inside an entity, or outside of any entity.

# %%
df = Preprocess.remove_non_ascii(df, column_name='text')
df = Preprocess.remove_usertag(df, column_name='text')
df = Preprocess.reformat_hashtag(df, column_name='text')
df = Preprocess.remove_prefix(df, df_type="train", text_column='text')
df = Preprocess.reformat_useless_char(df, column_name='text')
df.head(60)
# Out:
#                   tweet_id  \
# 0   ID_1001136212718088192
# 1   ID_1001136696589631488
# 2   ID_1001136950345109504
# 3   ID_1001137334056833024
# 4   ID_1001138374923579392
# 5   ID_1001138377717157888
# 6   ID_1001139323075416064
# 7   ID_1001140017207459840
# 8   ID_1001140276377935872
# 9   ID_1001140804503601152
# 10  ID_1001141041926492160
# 11  ID_1001141195576258560
# 12  ID_1001141289323319296
# 13  ID_1001141769155891200
# 14  ID_1001142381012508672
# 15  ID_1001143589630427136
# 16  ID_1001143679267098624
# 17  ID_1001144018451955712
# 18  ID_1001144314897018880
# 19  ID_1001144944717914112
# 20  ID_1001146215441068032
# 21  ID_1001146463701872640
# 22  ID_1001147515360677888
# 23  ID_1001147793904427008
# 24  ID_1001148349364490240
# 25  ID_1001148569863237632
# 26  ID_1001150622379503616
# 27  ID_1001150946028666880
# 28  ID_1001152279368683520
# 29  ID_1001152706374000640
# 30  ID_1001152750418350080
# 31  ID_1001152773814185984
# 32  ID_1001152780147576832
# 33  ID_1001153932310216704
# 34  ID_1001154242273533952
# 35  ID_1001155244011720704
# 36  ID_1001155359002607616
# 37  ID_1001155564901199872
# 38  ID_1001155973187162112
# 39  ID_1001156365992284160
# 40  ID_1001156790275510272
# 41  ID_1001156881220448256
# 42  ID_1001157849584566272
# 43  ID_1001158582619000832
# 44  ID_1001161182366126080
# 45  ID_1001161326020956160
# 46  ID_1001162007138185216
# 47  ID_1001162370390155264
# 48  ID_1001163799326425088
# 49  ID_1001164079187267584
# 50  ID_1001165180938719232
# 51  ID_1001165202870751232
# 52  ID_1001165258843664384
# 53  ID_1001165784016674816
# 54  ID_1001166109771431936
# 55  ID_1001166885130592256
# 56  ID_1001166979074412544
# 57  ID_1001168665688051712
# 58  ID_1001168701406593024
# 59  ID_1001169406649659392
#
#                                                                                                                                                                                                                                      text  \
# 0                                                                                                                                                                                        EllicottCity is known for its vibrant art scene.
# 1                                                                                                                                      Flash floods struck a Maryland city on Sunday washing out streets and tossing cars like bath toys.
# 2                                                                                                                                                                                 State of emergency declared for Maryland flooding:  via
# 3                           Other parts of Maryland also saw significant damage from Sundays storms including this Baltimore city neighborhood Dundalk and Catonsville. Rain totals spanned from 1 to 10 inches across Maryland:  ECFlood
# 4                                                                                                                                    Catastrophic Flooding Slams Ellicott City Maryland Water Rescues Reported - The Weather Channel  via
# 5                                                                                                                                                                  1 missing after flash FLOODING devastates Ellicott City Maryland  GPWX
# 6                                                                                                                                                                 The scenic spots in Ellicott City Maryland are perfect for photography.
# 7                                                                                                                                                                                         Maryland has a variety of historical landmarks.
# 8                                                                                                                                                                          The local food markets in Maryland are a feast for the senses.
# 9                                                                                                                                                                   Baltimore is a popular destination for both relaxation and adventure.
# 10                                                                                                                                                                                 Maryland is known for its beautiful parks and gardens.
# 11                                                                                                                                                                                         Ellicott Maryland has a rich musical heritage.
# 12                                                                                                                                                                                  Maryland has a variety of family-friendly activities.
# 13                                                                                                                                                             Aerials of damage after historic flash flooding in Ellicott City Maryland.
# 14                                                                                                                                                                 The local arts and crafts markets in Maryland are vibrant and diverse.
# 15                                                                                                                              One person is reported missing as a state of emergency is declared amid flash floods in Maryland  reports
# 16                                                                                        National Guardsman missing after monstrous floods sink Maryland town Trump visits Arlington after critics slam appalling Memorial Day tweet Via
# 17                                                                                                                                                                   The parks and gardens in Ellicott Maryland offer a peaceful retreat.
# 18                                                                                                                One man is still missing after flash flooding tore down historic Main Street in Ellicott City Maryland over the weekend
# 19                                                                                                                                                               State of emergency declared in Maryland after heavy rain causes flooding
# 20                                        Howard County Executive Allan Kittleman said Monday morning that his priorities are finding the missing man and assessing the condition of buildings that house shops restaurants and families.
# 21                                                                                                                                                                 The annual parades in Howard Ellicott Maryland are a major attraction.
# 22                                                                                                                        Governor Larry Hogan has declared a state of emergency for the entire state of Maryland after extreme flooding.
# 23                                                                                                                                                      Howard County officials searching for man reported missing in Ellicott City flood
# 24                                                                                                                                                                      The cultural events in Baltimore Maryland highlight its heritage.
# 25                  AdvantaClean of Frederick is available to help mitigate the damages to homes and businesses in Ellicott City and surrounding areas. Call 877-800-2382 toll free to connect with our office to get the job done right.
# 26                                                                                                                                           Historic Maryland city is ravaged by flood waters again. Search is underway for missing man.
# 27                                      Army National Guardsman missing after massive flooding hits Ellicott City Maryland. Thoughts and prayers with Eddison Alexander Hermond and his family. I sure hope they find him alive and well.
# 28                                                                                                                                                                     State of Emergency declared. Catastrophic flooding slams  Maryland
# 29                                             Please pray for a brave vet who is missing in Maryland in the flooding. Ellicott City Maryland flash floods leave National Guard member missing devastate town recovering from 2016 deluge
# 30                                                                                                                                                           Colombia Ellicott Maryland is known for its scenic views and natural beauty.
# 31                                                                                                                                                                         Ellicott City Maryland is a hub for technology and innovation.
# 32                               A state of emergency has been declared in the US state of Maryland as catastrophic flash floods swept Ellicott City after heavy rain. Officials have urged residents to go to higher ground immediately.
# 33                                                                                                                                                                         Ellicott Maryland has a variety of family-friendly activities.
# 34                                                                                                                                            I liked a  video  CRAZY MARYLAND FLOODING - Flash flood smashes into Ellicott City Maryland
# 35                                                                                                                                                      National Guard member missing after flash floods devastate historic Maryland town
# 36                                                                                                                            Missing   swept away in  Maryland floods while saving others: : . : SUN: 8-10aE/866.594.HOPE/iHeartRadio: /
# 37                  Crews have begun removing heavy debris  including cars and a dumpster  thrown by a wall of water that rushed through downtown Ellicott City Maryland Sunday afternoon 1 person remains missing as the town deals with
# 38                                                                                                                                                              Maryland Hit By Catastrophic Flash Flooding Second Time in Two Years  via
# 39                                                                                                                                                                             Maryland is famous for its unique architectural landmarks.
# 40                                                                                                                                                                      Flash Floods Surge Through Town in Maryland One Person Is Missing
# 41                                                                                                                                                         The local theater performances in Ellicott City Maryland are highly acclaimed.
# 42                                                                                                                                                                       The local history and traditions in Maryland are well-preserved.
# 43                                                                                                                          National Guardsman missing after flash flooding devastates Ellicott City Maryland: Im hopeful that hell be OK
# 44                                                                                   During the devastating Maryland flash floods witnesses said Eddison Alexander was swept away while helping a woman cross the waters in Ellicott City
# 45                                                                                                   Headed to the Howard County Food Bank with supplies. Please consider joining and bringing cleaning supplies food and water. ECStrong
# 46                                                             Man missing after 1000-year flood ravages Ellicott City for 2nd time in two years  Good thing Trump & his quislings are taking such good care of us - What climate change?
# 47                                                                                                          Officials in Maryland are looking for a National Guard member and Air Force veteran they say was swept away in weekend floods
# 48                                                                                                                                                                 Maryland man missing after Ellicott City devastated by rampaging flood
# 49                                                                                                                                                                                    The community events in Maryland are well-attended.
# 50                                                                                                                                                                                       The public libraries in Maryland are impressive.
# 51                                                                                                                                                                                    Maryland is a top destination for cultural tourism.
# 52                                                                                                                                      Hopeful that he will be OK. Search underway for man missing in Ellicott City Maryland flash flood
# 53  Ellicott City Maryland recovering from 2016 flood hammered again  flooding 25- to 30-ft-wide hole N of Main Street ground and road buckled. utilities off water ran thru bldgs Patapsco River up 17.8 ft in 2 hrs Sunday record level
# 54                                                     Watch Video Severe flooding in Ellicott City Maryland has submerged vehicles forced residents to evacuate and caused major damage to homes and businesses. Newsys partners at WMAR
# 55                                                                              Have you seen Eddison Hermond? The Army National Guard member is missing after devastating floods rolled through Ellicott City Maryland over the weekend.
# 56                                                                       Emergency workers are searching for 39-year-old Eddison Hermond in Ellicott City which was hit hard Sunday evening by flash flooding from an intense rain storm.
# 57                                                                                                     Search underway for a missing veteran Eddison Hermond reportedly swept away helping to rescue others from flash floods in Maryland
# 58                                                                                                                                                                    Ellicott Maryland is known for its scenic views and natural beauty.
# 59                                                                                                                                                                              A88ATTENTION8A8 MISSING HERO IN FLOOD WATERS in Maryland!
#
#                                  location  \
# 0                            EllicottCity
# 1                                Maryland
# 2                                Maryland
# 3                      Baltimore Maryland
# 4                  Ellicott City Maryland
# 5                  Ellicott City Maryland
# 6                  Ellicott City Maryland
# 7                                Maryland
# 8                                Maryland
# 9                               Baltimore
# 10                               Maryland
# 11                      Ellicott Maryland
# 12                               Maryland
# 13                 Ellicott City Maryland
# 14                               Maryland
# 15                               Maryland
# 16                     Arlington Maryland
# 17                      Ellicott Maryland
# 18                 Ellicott City Maryland
# 19                               Maryland
# 20                                 Howard
# 21               Howard Ellicott Maryland
# 22                               Maryland
# 23            Ellicott City Howard County
# 24                     Baltimore Maryland
# 25                          Ellicott City
# 26                               Maryland
# 27                 Ellicott City Maryland
# 28                               Maryland
# 29                      Ellicott Maryland
# 30             Colombia Ellicott Maryland
# 31                 Ellicott City Maryland
# 32              Ellicott City US Maryland
# 33                      Ellicott Maryland
# 34        Ellicott City MARYLAND Maryland
# 35                               Maryland
# 36                  EllicottCity Maryland
# 37                 Ellicott City Maryland
# 38                               Maryland
# 39                               Maryland
# 40                               Maryland
# 41                 Ellicott City Maryland
# 42                               Maryland
# 43                 Ellicott City Maryland
# 44                 Ellicott City Maryland
# 45                          Howard County
# 46                          Ellicott City
# 47                               Maryland
# 48                 Ellicott City Maryland
# 49                               Maryland
# 50                               Maryland
# 51                               Maryland
# 52                 Ellicott City Maryland
# 53  Ellicott City Patapsco River Maryland
# 54                 Ellicott City Maryland
# 55                      Ellicott Maryland
# 56                          Ellicott City
# 57                               Maryland
# 58                      Ellicott Maryland
# 59                               Maryland
#
#                                                                     location_mentions
# 0                                                                  EllicottCity=>CITY
# 1                                                                     Maryland=>STATE
# 2                                                                     Maryland=>STATE
# 3                                                   Baltimore=>CITY * Maryland=>STATE
# 4                                               Ellicott City=>CITY * Maryland=>STATE
# 5                                               Ellicott City=>CITY * Maryland=>STATE
# 6                                               Ellicott City=>CITY * Maryland=>STATE
# 7                                                                     Maryland=>STATE
# 8                                                                     Maryland=>STATE
# 9                                                                     Baltimore=>CITY
# 10                                                                    Maryland=>STATE
# 11                                                   Ellicott=>CITY * Maryland=>STATE
# 12                                                                    Maryland=>STATE
# 13                                              Ellicott City=>CITY * Maryland=>STATE
# 14                                                                    Maryland=>STATE
# 15                                                                    Maryland=>STATE
# 16                                                Arlington=>COUNTY * Maryland=>STATE
# 17                                                   Ellicott=>CITY * Maryland=>STATE
# 18                                              Ellicott City=>CITY * Maryland=>STATE
# 19                                                                    Maryland=>STATE
# 20                                                                     Howard=>COUNTY
# 21                                  Howard=>COUNTY * Ellicott=>CITY * Maryland=>STATE
# 22                                                                    Maryland=>STATE
# 23                                        Ellicott City=>CITY * Howard County=>COUNTY
# 24                                                  Baltimore=>CITY * Maryland=>STATE
# 25                                                                Ellicott City=>CITY
# 26                                                                    Maryland=>STATE
# 27                                              Ellicott City=>CITY * Maryland=>STATE
# 28                                                                    Maryland=>STATE
# 29                                                   Ellicott=>CITY * Maryland=>STATE
# 30                               Colombia=>COUNTRY * Ellicott=>CITY * Maryland=>STATE
# 31                                              Ellicott City=>CITY * Maryland=>STATE
# 32                                Ellicott City=>CITY * US=>COUNTRY * Maryland=>STATE
# 33                                                   Ellicott=>CITY * Maryland=>STATE
# 34                            Ellicott City=>CITY * MARYLAND=>STATE * Maryland=>STATE
# 35                                                                    Maryland=>STATE
# 36                                               EllicottCity=>CITY * Maryland=>STATE
# 37                                              Ellicott City=>CITY * Maryland=>STATE
# 38                                                                    Maryland=>STATE
# 39                                                                    Maryland=>STATE
# 40                                                                    Maryland=>STATE
# 41                                              Ellicott City=>CITY * Maryland=>STATE
# 42                                                                    Maryland=>STATE
# 43                                              Ellicott City=>CITY * Maryland=>STATE
# 44                                              Ellicott City=>CITY * Maryland=>STATE
# 45                                                              Howard County=>COUNTY
# 46                                                                Ellicott City=>CITY
# 47                                                                    Maryland=>STATE
# 48                                              Ellicott City=>CITY * Maryland=>STATE
# 49                                                                    Maryland=>STATE
# 50                                                                    Maryland=>STATE
# 51                                                                    Maryland=>STATE
# 52                                              Ellicott City=>CITY * Maryland=>STATE
# 53  Ellicott City=>CITY * Patapsco River=>NATURAL POINT-OF-INTEREST * Maryland=>STATE
# 54                                              Ellicott City=>CITY * Maryland=>STATE
# 55                                                   Ellicott=>CITY * Maryland=>STATE
# 56                                                                Ellicott City=>CITY
# 57                                                                    Maryland=>STATE
# 58                                                   Ellicott=>CITY * Maryland=>STATE
# 59                                                                    Maryland=>STATE

# %%
lemma_path = "../data/new/train.encoded2.lemma.csv"
if not os.path.exists(lemma_path):
    df_ = Preprocess.remove_stop_words(df, column_name='text', new_col="text_transformed", transformation=[
        "tokenize", "lemma-", "lower"
    ], save_in=lemma_path)
else:
    df_ = pd.read_csv(lemma_path)

# %%
# Subtitution

df = df_.drop(columns=['text'])
df = df.rename(columns={'text_transformed': 'text'})
df = df.dropna(subset=['text'])

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (43375, 4)
# tweet_id                0
# location                0
# location_mentions    1831
# text                    0
# dtype: int64

# %% [markdown]
# - Train dev split

# %%
df_idx, ner_classes = MultiLabelNERStratify.process_location_mentions(df)
train_idx, test_idx, train_label_freq, test_label_freq = MultiLabelNERStratify.stratify_train_test_split_multi_label(
    df_idx.tweet_id, 
    np.vstack(df_idx.location_array_freq.values), 
    test_size=0.2
)

# Filter the original DataFrame based on the tweet_id column
train_idx_list = train_idx.tolist() if hasattr(train_idx, 'tolist') else list(train_idx)
test_idx_list = test_idx.tolist() if hasattr(test_idx, 'tolist') else list(test_idx)
df_train = df[df['tweet_id'].isin(train_idx_list)]
df_dev   = df[df['tweet_id'].isin(test_idx_list)]

# print repartition
print("TRAIN SHAPE: ", df_train.shape)
print("DEV SHAPE: ", df_dev.shape)
# Out:
# TRAIN SHAPE:  (34123, 4)
# DEV SHAPE:  (9252, 4)

# %%
df_tag_train = Preprocess.build_bilou_encoding(df_train, text_col="text", save_in="../data/new/train.encoded.bilou.tag.csv")
df_tag_dev   = Preprocess.build_bilou_encoding(df_dev, text_col="text", save_in="../data/new/dev.encoded.bilou.tag.csv")

df_tag_train.head(5)
# Out:
#               sentence_id         words  labels
# 0  ID_1001136212718088192  ellicottcity  U-CITY
# 1  ID_1001136212718088192            is       O
# 2  ID_1001136212718088192         known       O
# 3  ID_1001136212718088192           for       O
# 4  ID_1001136212718088192           its       O

# %%
grouped = df_tag_train.groupby('sentence_id').agg({
    'words': lambda x: ' '.join(x),
    'labels': lambda x: ' '.join(x)
}).reset_index()
with open('../data/new/train.preprocessed_sentences.txt', 'w') as f_sentences:
    for sentence in grouped['words']:
        f_sentences.write(sentence + '\n')
with open('../data/new/train.preprocessed_labels.txt', 'w') as f_labels:
    for label in grouped['labels']:
        f_labels.write(label + '\n')

grouped = df_tag_dev.groupby('sentence_id').agg({
    'words': lambda x: ' '.join(x),
    'labels': lambda x: ' '.join(x)
}).reset_index()
with open('../data/new/dev.preprocessed_sentences.txt', 'w') as f_sentences:
    for sentence in grouped['words']:
        f_sentences.write(sentence + '\n')
with open('../data/new/dev.preprocessed_labels.txt', 'w') as f_labels:
    for label in grouped['labels']:
        f_labels.write(label + '\n')

# %% [markdown]
# ### **Prepare training, dev and test data**

# %%
df_tag_train["sentence_id"] = LabelEncoder().fit_transform(df_tag_train["sentence_id"])
df_tag_dev["sentence_id"]   = LabelEncoder().fit_transform(df_tag_dev["sentence_id"])

# %%
df_tag_train.head()
# Out:
#    sentence_id         words  labels
# 0            0  ellicottcity  U-CITY
# 1            0            is       O
# 2            0         known       O
# 3            0           for       O
# 4            0           its       O

# %%
X_train  = df_tag_train[["sentence_id", "words"]]
X_test   = df_tag_dev[["sentence_id", "words"]]
y_train  = df_tag_train["labels"]
y_test   = df_tag_dev["labels"]

train_data = pd.DataFrame({"sentence_id": X_train["sentence_id"], "words": X_train["words"], "labels": y_train})
test_data = pd.DataFrame({"sentence_id": X_test["sentence_id"], "words": X_test["words"], "labels": y_test})

train_data
# Out:
#         sentence_id         words     labels
# 0                 0  ellicottcity     U-CITY
# 1                 0            is          O
# 2                 0         known          O
# 3                 0           for          O
# 4                 0           its          O
# ...             ...           ...        ...
# 406450        34121        fellow          O
# 406451        34121        people          O
# 406452        34121            in          O
# 406453        34121        mexico  U-COUNTRY
# 406454        34121            2d          O
#
# [406455 rows x 3 columns]

# %% [markdown]
# #### **Model Training**

# %% [markdown]
# - Let count NER label

# %%
label = pd.concat([df_tag_train, df_tag_dev])["labels"].unique().tolist()
label_counts = pd.concat([df_tag_train, df_tag_dev])["labels"].value_counts().reset_index()
label_counts.columns = ["Label", "Frequency"]
display(label_counts)
# Out:
#              Label  Frequency
# 0                O     455787
# 1          U-STATE      18685
# 2        U-COUNTRY      11105
# 3           U-CITY       7490
# 4         B-ISLAND       3029
# 5         L-ISLAND       3029
# 6          B-STATE       2061
# 7          L-STATE       2061
# 8        L-COUNTRY       2053
# 9        B-COUNTRY       2053
# 10          B-CITY       1943
# 11          L-CITY       1943
# 12        U-ISLAND       1782
# 13         I-STATE        556
# 14       I-COUNTRY        481
# 15      U-DISTRICT        416
# 16        L-COUNTY        395
# 17        B-COUNTY        395
# 18          I-CITY        275
# 19     U-CONTINENT        264
# 20        U-COUNTY        227
# 21    L-HUMAN-MADE        220
# 22    B-HUMAN-MADE        220
# 23        I-ISLAND        195
# 24    I-HUMAN-MADE        181
# 25       L-NATURAL        166
# 26       B-NATURAL        166
# 27          I-ROAD        103
# 28          B-ROAD         71
# 29          L-ROAD         71
# 30       U-NATURAL         60
# 31    U-HUMAN-MADE         59
# 32      B-DISTRICT         48
# 33      L-DISTRICT         48
# 34        I-COUNTY         45
# 35  U-NEIGHBORHOOD         38
# 36  L-NEIGHBORHOOD         34
# 37  B-NEIGHBORHOOD         34
# 38       I-NATURAL         32
# 39         L-OTHER         27
# 40         B-OTHER         27
# 41         I-OTHER         17
# 42     B-CONTINENT         12
# 43     L-CONTINENT         12
# 44  I-NEIGHBORHOOD         12
# 45          U-ROAD         11
# 46      I-DISTRICT          6
# 47         U-OTHER          5

# %% [markdown]
# - Let define model **Args** and hyperparameters optimisation approach

# %%
model_args = NERArgs()

# general
model_args.evaluate_during_training = True
model_args.overwrite_output_dir = True
model_args.train_batch_size = 64
model_args.eval_batch_size = 32
model_args.labels_list = label
model_args.use_multiprocessing = True
model_args.num_train_epochs = 1
model_args.learning_rate = 4e-4

# for eaarly stoping
# model_args.use_early_stopping = True
# model_args.early_stopping_delta = 0.01
# model_args.early_stopping_metric = "wer"
# model_args.early_stopping_metric_minimize = False
# model_args.early_stopping_patience = 5
# model_args.wandb_project = "LMR-IO"
model_args.evaluate_during_training_steps = 1000

# %% [markdown]
# - Train

# %%
model = NERModel(
    "bert", 
    "rsuwaileh/IDRISI-LMR-EN-random-typebased", #bert-base-cased - #bert-large-uncased
    use_cuda=False,
    args=model_args, 
    ignore_mismatched_sizes=True
)

# Train the model
print('\n### TRAINING')
model.train_model(
    train_data, 
    eval_data=test_data, 
    wer=LMR_Metrics.wer_type
)
# Out:
# Some weights of the model checkpoint at rsuwaileh/IDRISI-LMR-EN-random-typebased were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at rsuwaileh/IDRISI-LMR-EN-random-typebased and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([49, 1024]) in the checkpoint and torch.Size([48, 1024]) in the model instantiated
# - classifier.bias: found shape torch.Size([49]) in the checkpoint and torch.Size([48]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ### TRAINING
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 1 of 1:   0%|          | 0/534 [00:00<?, ?it/s]

# %% [markdown]
# - Eval

# %%
# Evaluate the model
#print('\n### EVALUATION')
#result, model_outputs, wrong_preds = model.eval_model(test_data, wer=LMR_Metrics.wer_type)

# %%
#result

# %% [markdown]
# - Quick prediction

# %%
predictions, raw_outputs = model.predict([
    "Elicott City, Maryland, struck by catastrophic flooding; 1 missing.".lower(),
    "Memorial Day weekend floods ravage Maryland town".lower()
])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
predictions
# Out:
# [[{'elicott': 'B-CITY'},
#   {'city,': 'I-CITY'},
#   {'maryland,': 'B-STATE'},
#   {'struck': 'O'},
#   {'by': 'O'},
#   {'catastrophic': 'O'},
#   {'flooding;': 'O'},
#   {'1': 'O'},
#   {'missing.': 'O'}],
#  [{'memorial': 'O'},
#   {'day': 'O'},
#   {'weekend': 'O'},
#   {'floods': 'O'},
#   {'ravage': 'O'},
#   {'maryland': 'B-STATE'},
#   {'town': 'O'}]]

# %% [markdown]
# ### **Make prediction for Context**

# %%
df_context = pd.read_csv('../data/provided/Test.csv')
df_context = Preprocess.remove_non_ascii(df_context, column_name='text')
df_context = Preprocess.remove_usertag(df_context, column_name='text')
df_context = Preprocess.reformat_hashtag(df_context, column_name='text')
df_context = Preprocess.remove_prefix(df_context, df_type="test", text_column='text')
df_context = Preprocess.reformat_useless_char(df_context, column_name='text')
df_context.head(10)
# Out:
#                  tweet_id  \
# 0  ID_1001154804658286592
# 1  ID_1001155505459486720
# 2  ID_1001155756371136512
# 3  ID_1001159445194399744
# 4  ID_1001164907587538944
# 5  ID_1001178904617476096
# 6  ID_1001179909245587456
# 7  ID_1001180876548591616
# 8  ID_1001182906130280448
# 9  ID_1001185240256311296
#
#                                                                                                                                                                                                                                                                              text
# 0  What is happening to the infrastructure in New England? It isnt global warming its misappropriated funds being abused that shouldve been used maintaining their infrastructure that couldve protected them from floods! Like New Orleans. Their mayor went to 7Maryland floods
# 1                                                                                                                                                                                            SOLDER MISSING IN FLOOD.. PRAY FOR EDDISON HERMOND! PRAY FOR ELLICOTT CITY MARYLAND!
# 2                                                                                                                                                                                 Police searching for missing person after devastating 1000-year flood in Ellicott City Maryland
# 3                         Flash Flood Tears Through Maryland Town For Second Time In Two Years  Less than two years after what had been called a once in a 1000 years flood in 2016 Ellicott City Md. sees its historic downtown ravaged anew. One man remains missing. from Flas
# 4                                                                                                                                                                        Ellicott City FLOODING Pictures: Maryland Governor Declares State of Emergency After Severe Flash FLOODS
# 5                                                                                 Our Harts gos out to a Fellow Soldier missing in Maryland as he was HELPING Others the fast moving Water Consuming him. Well all on the island are praying for the missing Soldier in Maryland.
# 6  CRAZY VIDEO. Roaring flash floods struck a Maryland city Sunday that had been wracked by similar devastation two years ago its main street turned into a raging river that reached the first floor of some buildings and swept away parked cars authorities and witnesses say.
# 7                                                                                                                                                                                                 I liked a  video  BREAKING: Devastating flooding strikes Ellicott City Maryland
# 8                     Thank you to the first responders who are taking swift action to aid the Ellicott City community. The entire Maryland Delegation is working with  to bring in federal resources. If youre in the area please follow the guidance of local authorities and .
# 9                                                                                                                                                                     Ellicott City floods: Maryland officials assess destruction search for missing man in 1000-year flood.  via

# %%
lemma_path = "../data/new/test.encoded2.lemma.csv"
if not os.path.exists(lemma_path):
    df_context = Preprocess.remove_stop_words(df_context, column_name='text', new_col="text_transformed", transformation=[
        "tokenize", "lemma-", "lower"
    ], save_in=lemma_path)
else:
    df_context = pd.read_csv(lemma_path)
# Out:
# 100%|██████████| 2942/2942 [04:54<00:00,  9.97it/s]

# %%
df_context.isnull().sum()
# Out:
# tweet_id            0
# text                0
# text_transformed    0
# dtype: int64

# %%
ids = df_context["tweet_id"].values
tweets = df_context["text_transformed"].values

# Make prediction
predictions, raw_outputs = model.predict(tweets)

# Save submission file
results = []
for sentence in predictions:
    result = " ".join([word for d in sentence for word, tag in d.items() if tag != 'O'])
    if result == "":
        result = " "
    results.append(result)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Running Prediction:   0%|          | 0/92 [00:00<?, ?it/s]

# %%
Predictions.to_csv(ids, results)
# Out:
# Saved predictions to ../submissions/submission_14.csv

# %%
# Some Quick postprocessing
def remove_duplicate_words(file_path):
    df = pd.read_csv(file_path)
    def remove_duplicates(location):
        if pd.isna(location):
            return location
        words = location.split()
        unique_words = list(dict.fromkeys(words))
        loc = ' '.join(unique_words)
        return loc if loc != '' else ' '
    df['location'] = df['location'].apply(remove_duplicates)
    return df

# Usage
df_cleaned = remove_duplicate_words('../submissions/submission_13.csv')
df_cleaned.to_csv('../submissions/submission_13_post.csv', index=False)

# %%
### END
